# %%
import pandas as pd
arms_df = pd.read_csv("arms_transfers_export.csv")
arms_df = arms_df.drop(columns = [" ", " .1", " .2", "Comments"])
arms_df = arms_df[(arms_df["Recipient"] == "United States") | (arms_df["Supplier"] == "United States")]

# %%
arms_df.to_csv("arms_transfers_clean.csv", index=False)
